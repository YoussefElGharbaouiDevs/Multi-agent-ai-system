# %%
import tiktoken

# %%
tokenizer = tiktoken.encoding_for_model("gpt-4o")

# %%
print(tokenizer.name)
# Out:
# o200k_base

# %%
tokenizer = tiktoken.get_encoding("o200k_base")

# %%
query = "En tant qu'expert, donnez moi la definition d'un agent"

# %%
token_ids  = tokenizer.encode(query)

for token in token_ids :
    t= tokenizer.decode_single_token_bytes(token).decode("utf-8")
    print(f"ID{token} -> {t}", end="|\t")
# Out:
# ID1568 -> En|	ID16235 ->  tant|	ID474 ->  qu|	ID23472 -> 'ex|	ID3220 -> pert|	ID11 -> ,|	ID30004 ->  donne|	ID89 -> z|	ID18745 ->  moi|	ID557 ->  la|	ID16083 ->  definition|	ID272 ->  d|	ID9788 -> 'un|	ID11793 ->  agent|
